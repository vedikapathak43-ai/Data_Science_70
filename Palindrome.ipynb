# %% [markdown]
# <a href="https://colab.research.google.com/github/vedikapathak43-ai/Data_Science_70/blob/main/Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check if a number is a palindrome
def is_palindrome(number):
    # Convert the number to a string to easily reverse it
    num_str = str(number)

    # Reverse the string
    reversed_num_str = num_str[::-1]

    # Compare the original string with the reversed string
    if num_str == reversed_num_str:
        return True
    else:
        return False

# Get input from the user
while True:
    try:
        user_input = int(input("Enter a number: "))
        break
    except ValueError:
        print("Invalid input. Please enter an integer.")

# Check and print the result
if is_palindrome(user_input):
    print(f"{user_input} is a palindrome.")
else:
    print(f"{user_input} is not a palindrome.")
# Out:
# Enter a number: 343
# 343 is a palindrome.
