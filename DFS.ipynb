# %% [markdown]
# <a href="https://colab.research.google.com/github/vedikapathak43-ai/Data_Science_70/blob/main/DFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()

    result = []
    visited.add(start)
    result.append(start)

    for neighbor in graph[start]:
        if neighbor not in visited:
            result.extend(dfs(graph, neighbor, visited))

    return result


# Example graph (same structure as BFS)
graph_dfs = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['E']
}

print("DFS Traversal starting from 'A':", dfs(graph_dfs, 'A'))
# Out:
# DFS Traversal starting from 'A': ['A', 'B', 'D', 'E', 'F', 'C']
